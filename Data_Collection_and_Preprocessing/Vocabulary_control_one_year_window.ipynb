# %% [markdown]
# # Principles of vocabulary control for one year window (take contemperaneous return in 2023 as an example)
# 1. Remove stop words in English
# 2. Remove top 100 frequent words in each year's corpus
# 3. Remove words appearing once in each year's corpus; it's found that these words account for approximately 25% of the total vocabularies
# 4. **Most news sources are removed by removing top 100 frequent words**

# %%
import pandas as pd
import re
import collections
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

df = pd.read_csv("/scratch/wx2309/Processed_data/one_year_window/contem_2023.csv")
headlines = df.headline.tolist()

# %%
# Remove individual commenter first
def remove_individual(headline):
    by_pattern = re.search(r" (-+)? By", headline, flags = re.IGNORECASE)
    if by_pattern:
        return headline[:by_pattern.start()]
    else:
        return headline
df["vocab_con_headline"] = df.headline.apply(remove_individual)

# %%
# Tokenize the headline into tokens which are alphanumeric words including period . 
# longer than 2 because . is meaningful in financial news such as prices and some news
# sources like barrons.com and researchmarket.com
def custom_tokenizer(headline):
    tokens = re.findall(r"\b[a-zA-z0-9\.][a-zA-z0-9\.]+\b",headline.lower())  
    return tokens
# Remove tokens according to the principles 
def custom_processor(headline, remove_words):
    tokens = custom_tokenizer(headline)
    new_tokens = [token for token in tokens if token not in remove_words]
    return " ".join(new_tokens)

# %%
vocab = collections.Counter()
for headline in headlines:
    vocab.update(custom_tokenizer(headline))
remove_words = list(ENGLISH_STOP_WORDS)
words_once = [word for word,count in vocab.items() if count ==1]
top_100_count = sorted(vocab.values(),reverse = True)[99]
words_top_100 = [word for word,count in vocab.items() if count >=top_100_count]
remove_words.extend(words_once)
remove_words.extend(words_top_100)
remove_words = set(remove_words)

# %%
df.vocab_con_headline = df.vocab_con_headline.apply(lambda headline: custom_processor(headline, remove_words))

# %%
df.head()
# Out:
#          date rp_entity_id               comnam       ret  \
# 0  2023-01-03       3DC887  ARISTA NETWORKS INC -0.003626
# 1  2023-01-03       3DC887  ARISTA NETWORKS INC -0.003626
# 2  2023-01-03       3DC887  ARISTA NETWORKS INC -0.003626
# 3  2023-01-03       8EA478          MODERNA INC -0.003507
# 4  2023-01-03       8EA478          MODERNA INC -0.003507
#
#                                             headline  \
# 0  Network Monitoring Global Market Report 2022: ...
# 1  Network Monitoring Global Market Report 2022: ...
# 2  iRocket Appoints Kelyn Brannon to Board of Dir...
# 3             Official List Official List Notice -2-
# 4  DelveInsight Evaluates a Robust Cystic Fibrosi...
#
#                                   vocab_con_headline
# 0      network monitoring sector reach 3.8 2030 cagr
# 1  network monitoring corporations continue onlin...
# 2     irocket appoints kelyn brannon board directors
# 3                 official list official list notice
# 4  delveinsight evaluates robust cystic fibrosis ...

# %%
vocab_con_headlines = df.vocab_con_headline.tolist()
for headline, vocab_con_headline in zip(headlines[:99],vocab_con_headlines[:99]):
    print(f"{headline} / {vocab_con_headline}")
# Out:
# Network Monitoring Global Market Report 2022: Sector to Reach $3.8 Billion by 2030 with a 7% CAGR / network monitoring sector reach 3.8 2030 cagr
# Network Monitoring Global Market Report 2022: Corporations Continue to Move Online, Driving Demand - ResearchAndMarkets.com / network monitoring corporations continue online driving demand
# iRocket Appoints Kelyn Brannon to Board of Directors / irocket appoints kelyn brannon board directors
# Official List Official List Notice -2- / official list official list notice
# DelveInsight Evaluates a Robust Cystic Fibrosis Pipeline as 75+ Influential Pharma Players to Set Foot in the Domain / delveinsight evaluates robust cystic fibrosis pipeline 75 influential pharma players set foot domain
# London Stock Exchange Notice Admission to Trading - 03/01/2023 / london exchange notice admission trading 03 01
# DelveInsight Evaluates a Robust Cystic Fibrosis -2- / delveinsight evaluates robust cystic fibrosis
# CFA Drugs & Devices:Insider Review For Week Ended 30-Dec -2- / cfa drugs devices insider review week ended 30 dec
# Outlook on the Pharmaceutical Drugs Global Market to 2027: Look at the Changing Structure of the Pharma and Healthcare Industry / pharmaceutical drugs look changing structure pharma healthcare industry
# Moderna to Provide Business and Pipeline Updates at the 2023 J.P. Morgan Healthcare Conference / moderna provide pipeline updates j.p morgan healthcare
# Sterile Injectables Global Market Report 2022: Growing Demand for Biologics Bolsters Sector - ResearchAndMarkets.com / sterile injectables growing demand biologics bolsters sector
# ZielBio Appoints Alan Bash CEO as Company Advances Oncology Therapeutics / zielbio appoints alan bash ceo advances oncology therapeutics
# Propulsion of Pancreatic Cancer Pipeline as Novel -2- / propulsion pancreatic cancer pipeline novel
# GMP Cell Therapy Consumables Global Market Report 2022: Industry to Surpass $59.9 Billion by 2028 at a 27.5% CAGR / gmp cell therapy consumables industry surpass 59.9 2028 27.5 cagr
# Outlook on the Pharmaceutical Drugs Global Market to 2027: Look at the Changing Structure of the Pharma and Healthcare Industry / pharmaceutical drugs look changing structure pharma healthcare industry
# Press Release: Purple Biotech and Mor Research Applications Announce Research Collaboration to Identify Promising Investigational Oncology Treatments / purple biotech mor applications announce collaboration identify promising investigational oncology treatments
# Bristol Myers Squibb to Present at J.P. Morgan's 41(st) Annual Healthcare Conference / bristol myers squibb present j.p morgan 41 st annual healthcare
# Halozyme to Present at the 41st Annual J.P. Morgan Healthcare Conference / halozyme present 41st annual j.p morgan healthcare
# Purple Biotech and Mor Research Applications Announce Research Collaboration to Identify Promising Investigational Oncology Treatments / purple biotech mor applications announce collaboration identify promising investigational oncology treatments
# Bristol Myers Squibb Completes Sale of Manufacturing Facility in Syracuse, New York / bristol myers squibb completes sale manufacturing facility syracuse york
# Law Debenture Corp PLC Net Asset Value(s) -2- / law debenture net asset value
# Press Release: Bristol Myers Squibb to Present at J.P. Morgan's 41st Annual Healthcare Conference / bristol myers squibb present j.p morgan 41st annual healthcare
# Propulsion of Pancreatic Cancer Pipeline as Novel and Extensive 170+ Therapies Likely to Enter in the Treatment Domain | DelveInsight / propulsion pancreatic cancer pipeline novel extensive 170 therapies likely enter treatment domain delveinsight
# Treatment Resistant Depression Clinical Trial Analysis by Trial Phase, Trial Status, Trial Counts, End Points, Status, Sponsor Type, and Top Countries, 2022 Update - ResearchAndMarkets.com / treatment resistant depression clinical trial analysis trial phase trial status trial counts end points status sponsor type countries
# Press Release: Bristol Myers Squibb Completes Sale of Manufacturing Facility in Syracuse, New York / bristol myers squibb completes sale manufacturing facility syracuse york
# Bristol Myers Squibb Completes Sale of Manufacturing Facility in Syracuse, NY / bristol myers squibb completes sale manufacturing facility syracuse ny
# Press Release: Halozyme to Present at the 41st Annual J.P. Morgan Healthcare Conference / halozyme present 41st annual j.p morgan healthcare
# Bristol-Myers Squibb Price Target Raised to $78.00/Share From $70.00 by Wells Fargo / bristol myers squibb raised 78.00 70.00 wells fargo
# NACD New England Honors Citizens Financial, L.L. Bean as Public and Private Company Boards of the Year / nacd england honors citizens l.l bean public private boards
# GMP Cell Therapy Consumables Global Market Report 2022: Increasing Popularity of Strategic Collaborations Spurs Growth - ResearchAndMarkets.com / gmp cell therapy consumables increasing popularity strategic collaborations spurs
# Biopharmaceutical Executive Eric Strati joins Gift of Life Biologics as Chief Executive Officer / biopharmaceutical executive eric strati joins gift life biologics chief executive
# Berkshire Hathaway Had a Strong 2022. What to Watch in 2023. -- Barrons.com / berkshire hathaway strong watch
# Dow Falls 217 Points On Losses In Shares Of Apple, UnitedHealth / 217 points losses shares apple unitedhealth
# Dow's Nearly 100-point Drop Led By Losses In Shares Of Chevron, Apple / nearly 100 point drop led losses shares chevron apple
# Pudu Robotics to Continue Multi-functional and Multi-scene Strategy for its Commercial Service Robots Business in 2023 / pudu robotics continue multi functional multi scene strategy commercial service robots
# LONDON-BASED ENTREPRENEUR EMBARKS ON 4,000KM WALK IT BACK CAMPAIGN TO REVERSE HIS LIFETIME EMISSIONS / london based entrepreneur embarks 000km walk campaign reverse lifetime emissions
# Addverb and Velociti Alliance Partner to Bring Innovative Futuristic Automation to Convenience and Grocery Intralogistics / addverb velociti alliance partner bring innovative futuristic automation convenience grocery intralogistics
# Bill Ackman Again Hits Coke, Pepsi on Obesity -- Barrons.com / ackman hits coke pepsi obesity
# These "Nobodies" Are Shaking Up the Startup World: Nobody Studios Launches Unique Crowd-Infused(TM) Venture Studio, Offering Venture Wealth Creation, and Global Impact to Masses / nobodies shaking startup world studios unique crowd infused tm venture studio offering venture wealth creation impact masses
# PG&E Cut to Neutral From Buy by Jefferies / pg cut neutral buy jefferies
# MW PG&E downgraded to neutral from buy at UBS / pg downgraded neutral buy ubs
# PG&E Price Target Announced at $17.00/Share by Jefferies / pg announced 17.00 jefferies
# Correction to PG&E Ratings Headlines / correction pg ratings headlines
# Tyler Technologies to Participate in 25(th) Annual Needham Growth Conference / tyler technologies participate 25 th annual needham
# Press Release: Tyler Technologies to Participate in 25th Annual Needham Growth Conference / tyler technologies participate 25th annual needham
# Invitation Homes Price Target Cut to $31.00/Share From $38.00 by Jefferies / invitation homes cut 31.00 38.00 jefferies
# Invitation Homes Cut to Hold From Buy by Jefferies / invitation homes cut hold buy jefferies
# Innovator Announces Record Year for Defined -4- / innovator record defined
# Innovator Announces Record Year for Defined -3- / innovator record defined
# Press Release: Verizon Gizmo Watch 3 brings the fun and helps keep your children safe / verizon gizmo watch brings fun helps children safe
# Press Release: Verizon to speak at Citi conference January 4 / verizon speak citi january
# NGA and Verizon deliver Real-Time Text (RTT) in Logan County, W. Va. / nga verizon deliver real time text rtt logan county va
# Verizon Gizmo Watch 3 brings the fun and helps keep your children safe / verizon gizmo watch brings fun helps children safe
# Verizon to speak at Citi conference January 4 / verizon speak citi january
# FTC and Microsoft to Participate in Hearing Over Activision Deal -- Market Talk / ftc microsoft participate hearing activision deal
# Departure of CH Robinson CEO Could be a Positive -- Market Talk / departure ch robinson ceo positive
# Boeing Finds Solace In Choppers -- Market Talk / boeing finds solace choppers
# Internet of Things (IoT) Security: Technologies and Global Markets / internet things iot security technologies markets
# Drop in Tesla Shares Shows Risk of Thematic Investing -- Market Talk / drop tesla shares shows risk thematic investing
# mmWave 5G Global Market Report 2022: Growing Demand from Telecommunications, Medical and Security Services Bolsters Growth - ResearchAndMarkets.com / mmwave 5g growing demand telecommunications medical security services bolsters
# Blackstone Hopes New $4B Investment Will Allay Doubts About BREIT -- Market Talk / blackstone hopes 4b investment allay doubts breit
# T-Mobile's Outperformance Looks Set to Cool -- Market Talk / mobile outperformance looks set cool
# ISSB Plans to Finalize Rules on Disclosure of Climate-Related Risks in 2023 -- WSJ / issb plans finalize rules disclosure climate related risks
# Comstock Could Boost Dividend After First Payment in 8 Years, CFO Says -- Market Talk / comstock boost dividend payment years cfo says
# Tesla's Demand Fears Seen Mounting After Deliveries Miss -- Market Talk / tesla demand fears seen mounting deliveries miss
# Molson Coors Earnings Face Downside Risk -- Market Talk / molson coors face downside risk
# 3M Gears Up For Legal Fights That Could Cost Billions -- Market Talk / 3m gears legal fights cost billions
# Thinking about trading options or stock in Tesla, Raytheon, Verizon, Lowe's, or PayPal? / thinking trading tesla raytheon verizon lowe paypal
# Rules on Disclosure of Risks Related To Climate Expected to Be Finalized -- WSJ / rules disclosure risks related climate expected finalized
# TikTok And Netflix Are Challenging Advertising Dominance Of Old Guard -- Market Talk / tiktok netflix challenging advertising dominance old guard
# Rules on Disclosure of Risks Related  To Climate Expected to Be Finalized  ----  By Jennifer Williams-Alvarez / rules disclosure risks related climate expected finalized
# MW CES organizers aim for attendance to more than double as 'major companies want the physical connection' / ces organizers aim attendance double major companies want physical connection
# Treasurys, Dollar Rise In Cautious Start to New Year -- Market Talk / treasurys dollar rise cautious start
# Here Are Barron's 12 Best Income Investments for -2- / barron 12 best income investments
# Samsung Bioepis Announces Health Canada Approval of Citrate-Free High-Concentration of HUMIRA(R)(1) Biosimilar (adalimumab; SB5) / samsung bioepis canada approval citrate free high concentration humira biosimilar adalimumab sb5
# DoubleLine Yield Opportunities Fund Declares January 2023 Distribution / doubleline yield opportunities fund declares january distribution
# Press Release: DoubleLine Yield Opportunities Fund Declares January 2023 Distribution / doubleline yield opportunities fund declares january distribution
# Global 5G Testing Equipment Market to Grow by $515.76 Million During 2023-2027 - ResearchAndMarkets.com / 5g testing equipment 515.76
# Press Release: Analog Devices and Seeing Machines Work Together to Accelerate Safer Driving Through Sophisticated Advanced Driver Assistance Systems / analog devices seeing machines work accelerate safer driving sophisticated advanced driver assistance systems
# Analog Devices and Seeing Machines Work Together to Accelerate Safer Driving Through Sophisticated Advanced Driver Assistance Systems / analog devices seeing machines work accelerate safer driving sophisticated advanced driver assistance systems
# GMP Cell Therapy Consumables Global Market Report 2022: Industry to Surpass $59.9 Billion by 2028 at a 27.5% CAGR / gmp cell therapy consumables industry surpass 59.9 2028 27.5 cagr
# GMP Cell Therapy Consumables Global Market Report 2022: Increasing Popularity of Strategic Collaborations Spurs Growth - ResearchAndMarkets.com / gmp cell therapy consumables increasing popularity strategic collaborations spurs
# Protein Expression, Purification and Isolation Technology Market Report 2022-2032 / protein expression purification isolation 2032
# Colgate-Palmolive Is Maintained at Equal-Weight by Wells Fargo / colgate palmolive maintained equal weight wells fargo
# Colgate-Palmolive Price Target Raised to $80.00/Share From $75.00 by Wells Fargo / colgate palmolive raised 80.00 75.00 wells fargo
# RealWear Unveils Next Generation Assisted Reality Headset for Modern Frontline Professional with All New HyperDisplay / realwear unveils generation assisted reality headset modern frontline professional hyperdisplay
# The Global Digital Retail Marketing Market is expected to grow by $902.88 bn during 2022-2027, accelerating at a CAGR of 26.39% during the forecast period / digital retail marketing expected 902.88 bn accelerating cagr 26.39 forecast period
# NACD New England Honors Citizens Financial, L.L. Bean as Public and Private Company Boards of the Year / nacd england honors citizens l.l bean public private boards
# Google and Meta's Advertising Dominance Fades as TikTok, Netflix Emerge -- WSJ / google meta advertising dominance fades tiktok netflix emerge
# Google and Meta's Advertising Dominance Fades as TikTok, Streamers Emerge -- WSJ / google meta advertising dominance fades tiktok streamers emerge
# United Community Banks, Inc. Announces Completion of Merger With Progress Financial Corporation / united community banks completion merger progress
# Janus Henderson Fund Mgmnt UK Ltd. Net Asset -2- / janus henderson fund mgmnt uk net asset
# Austria Plans to Launch New 10-Year Government Bond / austria plans launch 10 government bond
# Banks Likely to Absorb Increased Government Bond Supply in UK and EU -- Market Talk / banks likely absorb increased government bond supply uk eu
# Conagra Likely To Top Earnings Expectations, Says UBS -- Market Talk / conagra likely expectations says ubs
# Heard on the Street:  Global Trade Is Shifting, Not Reversing  ---  Mexico is one country well-placed to take advantage of U.S.-China trade war  ----  By Stephen Wilmot / heard street trade shifting reversing mexico country placed advantage china trade war
# Becton Dickinson Raised to Buy From Neutral by B of A Securities / becton dickinson raised buy neutral
# Year-End Review & Outlook: Markets & Finance  ---  Gold's Prospects Hinge On Fed Moves  ---  Precious metal fell for second straight year; bullish bets expect a less-hawkish central bank  ----  By Hardika Singh / end review markets finance gold prospects hinge fed moves precious metal fell second straight bullish bets expect hawkish central
# Ambac Settles RMBS Litigation Against Nomura / ambac settles rmbs litigation nomura

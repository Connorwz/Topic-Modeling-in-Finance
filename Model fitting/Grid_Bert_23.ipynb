# %%
import pandas as pd
import numpy as np
# Load data
dp = pd.read_csv('data/sp500_2023_ret_headline.csv')
headline = dp['headline']

# %%
from sentence_transformers import SentenceTransformer
# Pre-calculate embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = embedding_model.encode(headline, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/71639 [00:00<?, ?it/s]

# %%
np.save('data/Grid_Bert_23_embeddings.npy', embeddings)

# %%
from umap import UMAP

# Reduce dimensionality
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine', random_state=42)
# Out:
# 2024-05-21 11:17:51.924393: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-21 11:18:29.877165: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from hdbscan import HDBSCAN

# Cluster embeddings
hdbscan_model = HDBSCAN(min_cluster_size=150, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Vectorize
vectorizer_model = CountVectorizer(stop_words="english", min_df=0.1, max_df = 0.9, ngram_range=(1, 3), max_features=10000)

# %%
import openai
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance, OpenAI, PartOfSpeech

# KeyBERT
keybert_model = KeyBERTInspired()

# Part-of-Speech
pos_model = PartOfSpeech("en_core_web_sm")

# MMR
mmr_model = MaximalMarginalRelevance(diversity=0.3)

# GPT-3.5
client = openai.OpenAI(api_key="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")
prompt = """
I have a topic that contains the following documents: 
[DOCUMENTS]
The topic is described by the following keywords: [KEYWORDS]

Based on the information above, extract a short but highly descriptive topic label of at most 5 words. Make sure it is in the following format:
topic: <topic label>
"""
openai_model = OpenAI(client, model="gpt-3.5-turbo", exponential_backoff=True, chat=True, prompt=prompt)

# All representation models
representation_model = {
    "KeyBERT": keybert_model,
    "OpenAI": openai_model,  # Uncomment if you will use OpenAI
    "MMR": mmr_model,
    "POS": pos_model
}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 8
#       5 keybert_model = KeyBERTInspired()
#       7 # Part-of-Speech
# ----> 8 pos_model = PartOfSpeech("en_core_web_sm")
#      10 # MMR
#      11 mmr_model = MaximalMarginalRelevance(diversity=0.3)
#
# File ~/.local/lib/python3.11/site-packages/bertopic/_utils.py:100, in NotInstalled.__call__(self, *args, **kwargs)
#      99 def __call__(self, *args, **kwargs):
# --> 100     raise ModuleNotFoundError(self.msg)
#
# ModuleNotFoundError: In order to use Part of Speech with Spacy you will need to install via;
#
# pip install bertopic[spacy]

# %%
from bertopic import BERTopic

# Create BERTopic model
topic_model = BERTopic(

  # Pipeline models
  embedding_model=embedding_model,
  umap_model=umap_model,
  hdbscan_model=hdbscan_model,
  vectorizer_model=vectorizer_model,
  #representation_model=representation_model,
  calculate_probabilities=False,
  low_memory = True,
    

  # Hyperparameters
  top_n_words=10,
  verbose=True
)

# Train model
topics, probs = topic_model.fit_transform(headline, embeddings)

# Show topics
topic_model.get_topic_info()
# Out:
# 2024-05-21 11:21:00,446 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[8], line 22
#       4 topic_model = BERTopic(
#       5
#       6   # Pipeline models
#    (...)
#      18   verbose=True
#      19 )
#      21 # Train model
# ---> 22 topics, probs = topic_model.fit_transform(headline, embeddings)
#      24 # Show topics
#      25 topic_model.get_topic_info()
#
# File ~/.local/lib/python3.11/site-packages/bertopic/_bertopic.py:408, in BERTopic.fit_transform(self, documents, embeddings, images, y)
#     405         return self._combine_zeroshot_topics(documents, assigned_documents, assigned_embeddings)
#     407 # Reduce dimensionality
# --> 408 umap_embeddings = self._reduce_dimensionality(embeddings, y)
#     410 # Cluster reduced embeddings
#     411 documents, probabilities = self._cluster_embeddings(umap_embeddings, documents, y=y)
#
# File ~/.local/lib/python3.11/site-packages/bertopic/_bertopic.py:3355, in BERTopic._reduce_dimensionality(self, embeddings, y, partial_fit)
#    3352 try:
#    3353     # cuml umap needs y to be an numpy array
#    3354     y = np.array(y) if y is not None else None
# -> 3355     self.umap_model.fit(embeddings, y=y)
#    3356 except TypeError:
#    3358     self.umap_model.fit(embeddings)
#
# File ~/.local/lib/python3.11/site-packages/umap/umap_.py:2612, in UMAP.fit(self, X, y, force_all_finite)
#    2606     nn_metric = self._input_distance_func
#    2607 if self.knn_dists is None:
#    2608     (
#    2609         self._knn_indices,
#    2610         self._knn_dists,
#    2611         self._knn_search_index,
# -> 2612     ) = nearest_neighbors(
#    2613         X[index],
#    2614         self._n_neighbors,
#    2615         nn_metric,
#    2616         self._metric_kwds,
#    2617         self.angular_rp_forest,
#    2618         random_state,
#    2619         self.low_memory,
#    2620         use_pynndescent=True,
#    2621         n_jobs=self.n_jobs,
#    2622         verbose=self.verbose,
#    2623     )
#    2624 else:
#    2625     self._knn_indices = self.knn_indices
#
# File ~/.local/lib/python3.11/site-packages/umap/umap_.py:330, in nearest_neighbors(X, n_neighbors, metric, metric_kwds, angular, random_state, low_memory, use_pynndescent, n_jobs, verbose)
#     327     n_trees = min(64, 5 + int(round((X.shape[0]) ** 0.5 / 20.0)))
#     328     n_iters = max(5, int(round(np.log2(X.shape[0]))))
# --> 330     knn_search_index = NNDescent(
#     331         X,
#     332         n_neighbors=n_neighbors,
#     333         metric=metric,
#     334         metric_kwds=metric_kwds,
#     335         random_state=random_state,
#     336         n_trees=n_trees,
#     337         n_iters=n_iters,
#     338         max_candidates=60,
#     339         low_memory=low_memory,
#     340         n_jobs=n_jobs,
#     341         verbose=verbose,
#     342         compressed=False,
#     343     )
#     344     knn_indices, knn_dists = knn_search_index.neighbor_graph
#     346 if verbose:
#
# File ~/.local/lib/python3.11/site-packages/pynndescent/pynndescent_.py:817, in NNDescent.__init__(self, data, metric, metric_kwds, n_neighbors, n_trees, leaf_size, pruning_degree_multiplier, diversify_prob, n_search_trees, tree_init, init_graph, init_dist, random_state, low_memory, max_candidates, max_rptree_depth, n_iters, delta, n_jobs, compressed, parallel_batch_queries, verbose)
#     815     if verbose:
#     816         print(ts(), "Building RP forest with", str(n_trees), "trees")
# --> 817     self._rp_forest = make_forest(
#     818         data,
#     819         n_neighbors,
#     820         n_trees,
#     821         leaf_size,
#     822         self.rng_state,
#     823         current_random_state,
#     824         self.n_jobs,
#     825         self._angular_trees,
#     826         self._bit_trees,
#     827         max_depth=self.max_rptree_depth,
#     828     )
#     829     leaf_array = rptree_leaf_array(self._rp_forest)
#     830 else:
#
# File ~/.local/lib/python3.11/site-packages/pynndescent/rp_trees.py:1388, in make_forest(data, n_neighbors, n_trees, leaf_size, rng_state, random_state, n_jobs, angular, bit_tree, max_depth)
#    1377         result = joblib.Parallel(n_jobs=n_jobs, require="sharedmem")(
#    1378             joblib.delayed(make_dense_bit_tree)(
#    1379                 data,
#    (...)
#    1385             for i in range(n_trees)
#    1386         )
#    1387     else:
# -> 1388         result = joblib.Parallel(n_jobs=n_jobs, require="sharedmem")(
#    1389             joblib.delayed(make_dense_tree)(
#    1390                 data,
#    1391                 rng_states[i],
#    1392                 leaf_size,
#    1393                 angular,
#    1394                 max_depth=max_depth
#    1395             )
#    1396             for i in range(n_trees)
#    1397         )
#    1398 except (RuntimeError, RecursionError, SystemError):
#    1399     warn(
#    1400         "Random Projection forest initialisation failed due to recursion"
#    1401         "limit being reached. Something is a little strange with your "
#    1402         "graph_data, and this may take longer than normal to compute."
#    1403     )
#
# File /apps/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File /apps/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File /apps/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File /apps/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /apps/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File /apps/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /apps/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /apps/anaconda3/lib/python3.11/site-packages/numba/typed/listobject.py:607, in impl()
#     605     raise ValueError('list is immutable')
#     606 elif status == ListStatus.LIST_ERR_NO_MEMORY:
# --> 607     raise MemoryError('Unable to allocate memory to append item')
#     608 else:
#     609     raise RuntimeError('list.append failed unexpectedly')
#
# MemoryError: Unable to allocate memory to append item

# %%
chatgpt_topic_labels = {topic: " | ".join(list(zip(*values))[0]) for topic, values in topic_model.topic_aspects_["OpenAI"].items()}
chatgpt_topic_labels[-1] = "Outlier Topic"
topic_model.set_topic_labels(chatgpt_topic_labels)
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1  16691     -1_stock_outperforms_competitors_underperforms
# 1       0   1954  0_healthcare conference_morgan healthcare_heal...
# 2       1   1028                  1_00_price target_target_00 share
# 3       2    930                            2_ces_ces 2023_2023_new
# 4       3    883                  3_net asset_asset value_net_asset
# 5       4    696           4_quarter_fourth quarter_fourth_earnings
# 6       5    691                               5_stocks_mw_fed_jobs
# 7       6    664                 6_registers_vp_surrenders_acquires
# 8       7    577                           7_plc_form_voting_rights
# 9       8    552            8_sky news_news_newly released_released
# 10      9    508                     9_sports_sky sports_sky_hamlin
# 11     10    492                 10_data talk_brands_data_walgreens
# 12     11    457       11_maintained_overweight_weight_equal weight
# 13     12    398                12_chief_officer_president_appoints
# 14     13    398      13_stock rises_rises_outperforms market_stock
# 15     14    392                     14_pgr_release pgr_moody_rates
# 16     15    351                     15_investors_action_class_firm
# 17     16    339  16_stock falls_falls_underperforms market_fall...
# 18     17    292  17_market strong_strong trading_trading day_st...
# 19     18    252  18_researchandmarkets_researchandmarkets com_c...
# 20     19    202               19_wheat_variable rate_variable_rate
# 21     20    192  20_growth conference_needham_needham growth_an...
# 22     21    171             21_tesla_tesla stock_stock rises_rises
# 23     22    170  22_stock outperforms_day_strong trading_tradin...
# 24     23    167                     23_ice_futures_jan_commitments
# 25     24    154                       24_cl_cl stock_corp cl_stock
#
#                                    CustomName  \
# 0                               Outlier Topic
# 1         Healthcare Conference Presentations
# 2                  Stock Price Target Changes
# 3       CES 2023 Electric Vehicle Innovations
# 4                         Asset Value Reports
# 5              Earnings Conference Calls 2022
# 6             Stocks Slide After Fed Comments
# 7                VP Registration Activity Inc
# 8             Voting Rights Holdings Analysis
# 9                         Global News Updates
# 10             Sky Sports Highlights and News
# 11                        Data Talk on Brands
# 12              Fargo's Weight Ratings Update
# 13    Executive Appointments in Tech Industry
# 14          Rising Stock Performance Analysis
# 15               Credit Rating Press Releases
# 16     Securities Class Action Deadline Alert
# 17           Stock Falls PerkinElmer Thursday
# 18         Strong Stock Performance in Market
# 19       Global Biorefinery Industry Forecast
# 20                 Wheat Options Close Jan 05
# 21            Growth Conference Presentations
# 22           Tesla Stock Performance Analysis
# 23          Novavax stock trading performance
# 24             ICE Futures Jan 06 Comittments
# 25  Stock Falls Thursday Underperforms Market
#
#                                        Representation  \
# 0   [stock, outperforms, competitors, underperform...
# 1   [healthcare conference, morgan healthcare, hea...
# 2   [00, price target, target, 00 share, price, sh...
# 3   [ces, ces 2023, 2023, new, electric, unveils, ...
# 4   [net asset, asset value, net, asset, value, ms...
# 5   [quarter, fourth quarter, fourth, earnings, re...
# 6   [stocks, mw, fed, jobs, gas, oil, jobs data, d...
# 7   [registers, vp, surrenders, acquires, officer,...
# 8   [plc, form, voting, rights, holding, total, ho...
# 9   [sky news, news, newly released, released, new...
# 10  [sports, sky sports, sky, hamlin, damar, damar...
# 11  [data talk, brands, data, walgreens, weston, b...
# 12  [maintained, overweight, weight, equal weight,...
# 13  [chief, officer, president, appoints, vice pre...
# 14  [stock rises, rises, outperforms market, stock...
# 15  [pgr, release pgr, moody, rates, notes, press ...
# 16  [investors, action, class, firm, encourages, d...
# 17  [stock falls, falls, underperforms market, fal...
# 18  [market strong, strong trading, trading day, s...
# 19  [researchandmarkets, researchandmarkets com, c...
# 20  [wheat, variable rate, variable, rate, today, ...
# 21  [growth conference, needham, needham growth, a...
# 22  [tesla, tesla stock, stock rises, rises, stock...
# 23  [stock outperforms, day, strong trading, tradi...
# 24  [ice, futures, jan, commitments, jan 06, 06, c...
# 25  [cl, cl stock, corp cl, stock, stock falls, fa...
#
#                                               KeyBERT  \
# 0   [stock outperforms, stock underperforms, outpe...
# 1   [morgan healthcare, therapeutics, healthcare c...
# 2   [price target, target raised, wells fargo, pri...
# 3   [ces 2023, 2023 new, 2023 press, 2023 2032, 20...
# 4   [net asset, asset value, asset, value, investm...
# 5   [earnings conference, conference press, confer...
# 6   [jobs data, wsj stocks, marketwatch mw, stocks...
# 7   [vp, network corp, acquires, registers, pgr, i...
# 8   [plc announces, plc, trust plc, morgan stanley...
# 9   [sky news, new book, news, book, faith, covid ...
# 10  [sky sports, sports, sky, players, 2023 sky, p...
# 11  [walgreens boots, release walgreens, walgreens...
# 12  [equal weight, wells fargo, weight morgan, ove...
# 13  [chief executive, appoints, executive vice, pr...
# 14  [stock rises, stock outperforms, rises tuesday...
# 15  [press release, release pgr, release, pgr, ann...
# 16  [securities, investors, counsel, law firm, hol...
# 17  [stock falls, stock rises, stock, salesforce s...
# 18  [stock outperforms, market strong, outperforms...
# 19  [2027 researchandmarkets, industry 2027, growt...
# 20  [wheat, cbot, options close, close jan, option...
# 21  [needham growth, growth conference, annual nee...
# 22  [tesla stock, stock rises, mw tesla, tesla, st...
# 23  [stock outperforms, outperforms competitors, c...
# 24  [futures, commitments, calendar 2023, ice, 202...
# 25  [stock falls, stock outperforms, stock underpe...
#
#                                          OpenAI  \
# 0      [Stock Performance Comparison in Market]
# 1         [Healthcare Conference Presentations]
# 2                  [Stock Price Target Changes]
# 3       [CES 2023 Electric Vehicle Innovations]
# 4                         [Asset Value Reports]
# 5              [Earnings Conference Calls 2022]
# 6             [Stocks Slide After Fed Comments]
# 7                [VP Registration Activity Inc]
# 8             [Voting Rights Holdings Analysis]
# 9                         [Global News Updates]
# 10             [Sky Sports Highlights and News]
# 11                        [Data Talk on Brands]
# 12              [Fargo's Weight Ratings Update]
# 13    [Executive Appointments in Tech Industry]
# 14          [Rising Stock Performance Analysis]
# 15               [Credit Rating Press Releases]
# 16     [Securities Class Action Deadline Alert]
# 17           [Stock Falls PerkinElmer Thursday]
# 18         [Strong Stock Performance in Market]
# 19       [Global Biorefinery Industry Forecast]
# 20                 [Wheat Options Close Jan 05]
# 21            [Growth Conference Presentations]
# 22           [Tesla Stock Performance Analysis]
# 23          [Novavax stock trading performance]
# 24             [ICE Futures Jan 06 Comittments]
# 25  [Stock Falls Thursday Underperforms Market]
#
#                                                   MMR  \
# 0   [stock, outperforms, competitors, underperform...
# 1   [healthcare conference, morgan healthcare, hea...
# 2   [00, price target, target, 00 share, price, sh...
# 3   [ces, ces 2023, 2023, new, electric, unveils, ...
# 4   [net asset, asset value, net, asset, value, ms...
# 5   [quarter, fourth quarter, fourth, earnings, re...
# 6   [stocks, mw, fed, jobs, gas, oil, jobs data, d...
# 7   [registers, vp, surrenders, acquires, officer,...
# 8   [plc, form, voting, rights, holding, total, ho...
# 9   [sky news, news, newly released, released, new...
# 10  [sports, sky sports, sky, hamlin, damar, damar...
# 11  [data talk, brands, data, walgreens, weston, b...
# 12  [maintained, overweight, weight, equal weight,...
# 13  [chief, officer, president, appoints, vice pre...
# 14  [stock rises, rises, outperforms market, stock...
# 15  [pgr, release pgr, moody, rates, notes, press ...
# 16  [investors, action, class, firm, encourages, d...
# 17  [stock falls, falls, underperforms market, fal...
# 18  [market strong, strong trading, trading day, s...
# 19  [researchandmarkets, researchandmarkets com, c...
# 20  [wheat, variable rate, variable, rate, today, ...
# 21  [growth conference, needham, needham growth, a...
# 22  [tesla, tesla stock, stock rises, rises, stock...
# 23  [stock outperforms, day, strong trading, tradi...
# 24  [ice, futures, jan, commitments, jan 06, 06, c...
# 25  [cl, cl stock, corp cl, stock, stock falls, fa...
#
#                                                   POS  \
# 0   [stock, global, trading, options, energy, stoc...
# 1   [healthcare, annual, conference, present, 41st...
# 2   [target, price, shares, stock, practices, auto...
# 3   [new, electric, vehicle, industry, technology,...
# 4    [dividend, payments, shareholders, , , , , , , ]
# 5   [quarter, fourth quarter, fourth, earnings, re...
# 6   [stocks, jobs, gas, oil, data, rate, futures, ...
# 7                                [, , , , , , , , , ]
# 8   [voting, rights, total, company, shares, capit...
# 9   [book, life, story, new book, faith, new, powe...
# 10                               [, , , , , , , , , ]
# 11                               [, , , , , , , , , ]
# 12  [overweight, weight, equal weight, equal, neut...
# 13  [chief, officer, names, new, operating, , , , , ]
# 14                               [, , , , , , , , , ]
# 15   [bonds, results, process, extension, , , , , , ]
# 16  [investors, action, class, deadline, securitie...
# 17             [stock, cap, time, months, , , , , , ]
# 18                               [, , , , , , , , , ]
# 19  [global, materials, forecast, period, generati...
# 20                               [, , , , , , , , , ]
# 21                           [25th, , , , , , , , , ]
# 22  [stock, years, deliveries, lowest, price, day,...
# 23                               [, , , , , , , , , ]
# 24                               [, , , , , , , , , ]
# 25                               [, , , , , , , , , ]
#
#                                   Representative_Docs
# 0   [Adobe Inc. Stock Outperforms Competitors On S...
# 1   [Press Release: TG Therapeutics to Present at ...
# 2   [RealReal Price Target Cut to $2.00/Share From...
# 3   [Press Release: Blink Charging Unveils Five Ne...
# 4   [iShares VII UTB 3-7 UCITS (ACC) $ Net Asset V...
# 5   [Press Release: Radware Schedules Conference C...
# 6   [MW U.S. stocks slide on jobs data, hawkish Fe...
# 7   [VP Lacy Surrenders 242 Of UDR Inc >UDR, VP Ga...
# 8   [Morgan Stanley & Co. Int'l plc Form 8.5 (EPT/...
# 9   [WHO 'Really Concerned' About COVID Situation ...
# 10  [Baumgardner: Mayer Can Wait, Now I'm Shooting...
# 11  [Walgreens Boots Alliance Reports Fiscal 2023 ...
# 12  [RealReal Cut to Equal-Weight From Overweight ...
# 13  [Press Release: Vivendi: Gameloft Appoints Ale...
# 14  [Tapestry Inc. Stock Rises Tuesday, Outperform...
# 15  [Press Release: S&PGR Asgns Pinewood Fire Dist...
# 16  [VERU SHAREHOLDER ALERT: ROSEN, A TOP RANKED L...
# 17  [PerkinElmer Inc. Stock Falls Thursday, Underp...
# 18  [Paychex Inc. Stock Outperforms Market On Stro...
# 19  [Global Market for Biobased and Biodegradable ...
# 20  [CBOT Wheat Options Close - Jan 05 -2-, CBOT W...
# 21  [UiPath to Present at the 25th Annual Needham ...
# 22  [MW Tesla stock wipes out three-day bounce, fa...
# 23  [Novavax Inc. Stock Outperforms Competitors On...
# 24  [CFTC Commitments: ICE Sugar Futures - Jan 06,...
# 25  [News Corp Cl A Stock Falls Thursday, Underper...

# %%
topic_distr, _ = topic_model.approximate_distribution(headline)
#topic_distr is a n x m matrix where n are the topics and m the documents. We can then visualize the distribution of topics in a document.
topic_distr = pd.DataFrame(topic_distr)
topic_distr

# %%
#aggregate each company's topic exposures each day
index = 0
days = dp['date']
companies = dp['permno']
topic_num = topic_distr.shape[1]

agg_df = pd.DataFrame()
agg_df["date"] = days
agg_df["company"] = companies
agg_df["ret"] = dp['ret']

#merge topic_distr with agg_df
agg_df = pd.concat([agg_df, topic_distr], axis=1)

#rename columns
agg_df.columns = ["date", "company", "ret"] + ["topic_" + str(i + 1) for i in range(topic_num)]

#aggregate each company's topic exposures each day
agg_df = agg_df.groupby(["date", "company", "ret"], sort = False).sum().reset_index()
#sort by company and date
agg_df = agg_df.sort_values(by = ["company", "date"], ignore_index = True)
agg_df

#drop outliers, replace topic_exposure > 100 with 1
# agg_df.iloc[:, 3:] = agg_df.iloc[:, 3:].clip(upper = 50)
# agg_df
# Out:
#           date  company       ret    topic_1   topic_2    topic_3   topic_4  \
# 0     2023/1/3    10104  0.024223   0.000000  0.000000   2.106822  0.000000
# 1     2023/1/4    10104  0.009078   1.436034  0.000000   3.961611  0.000000
# 2     2023/1/5    10104 -0.002012   0.794239  2.000000   2.239412  0.000000
# 3     2023/1/6    10104  0.016012   0.303172  0.000000   0.653039  0.000000
# 4     2023/1/3    10107 -0.001001  83.412645  3.717476  47.344967  3.025995
# ...        ...      ...       ...        ...       ...        ...       ...
# 1772  2023/1/6    93429 -0.002262   0.000000  0.000000   0.000000  0.000000
# 1773  2023/1/3    93436 -0.122422   0.072187  3.278765   2.135957  0.000000
# 1774  2023/1/4    93436  0.051249   0.000000  2.525622   3.319081  0.000000
# 1775  2023/1/5    93436 -0.029039   0.133479  1.580263   3.245940  1.340552
# 1776  2023/1/6    93436  0.024651   0.000000  1.193012   1.858097  3.678185
#
#         topic_5    topic_6   topic_7  ...   topic_16  topic_17  topic_18  \
# 0      0.000000   0.000000  0.000000  ...   0.000000  0.000000  0.000000
# 1      1.674169   1.068066  0.000000  ...   0.000000  1.866024  0.752970
# 2      0.428667   0.711916  1.537805  ...   1.000000  0.519467  0.676334
# 3      1.569746   0.000000  0.000000  ...   0.000000  2.571093  0.239538
# 4     44.012265   9.424005  4.835909  ...  31.439623  0.662840  0.500128
# ...         ...        ...       ...  ...        ...       ...       ...
# 1772   0.478594   0.586416  0.000000  ...   0.000000  0.410530  1.030486
# 1773   5.581603  12.249522  0.000000  ...   1.168878  1.214592  0.964179
# 1774   1.609239  14.730206  0.316826  ...   1.320130  1.815835  1.497449
# 1775   2.563166   8.111830  0.000000  ...   0.490946  0.383714  0.732782
# 1776   2.774123  10.910647  0.552055  ...   0.637629  1.170138  1.152165
#
#        topic_19  topic_20   topic_21   topic_22  topic_23  topic_24  topic_25
# 0      5.699434  0.000000   0.056947   0.000000  1.000000  0.000000  0.000000
# 1      9.316722  0.000000   1.493938   0.389043  1.703532  0.000000  1.682725
# 2      6.466521  0.000000   0.000000   1.089898  0.882205  0.000000  0.934168
# 3      5.080517  0.000000   0.700622   0.153336  1.430320  0.000000  2.255549
# 4     21.433908  1.056901  26.519599   2.164499  0.156774  0.000000  0.000000
# ...         ...       ...        ...        ...       ...       ...       ...
# 1772   0.000000  0.000000   0.000000   0.079011  0.018359  1.000000  2.528101
# 1773   0.788651  4.617672   0.078229  20.180251  2.010494  1.042299  0.124055
# 1774   1.509737  3.183657   0.337654  15.415663  1.593878  0.999922  1.247877
# 1775   1.367356  3.462956   0.000000   8.017667  0.601475  0.000000  0.834020
# 1776   1.047569  3.902153   1.217434  12.680477  1.531215  1.972670  0.770435
#
# [1777 rows x 28 columns]

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import statsmodels.api as sm

#multi regress return on the topic exposures
returns = agg_df["ret"].values.reshape(-1, 1)
topics = agg_df.iloc[:, 3:].values
model_sk = LinearRegression()
model_sk.fit(topics, returns)

# Add a constant to the independent variable for the intercept
X = sm.add_constant(topics)
# Fit the regression model
model_sm = sm.OLS(returns, X).fit()
# Print the summary of the regression
print(model_sm.summary())
print("\n")

#plot the coefficients
plt.figure(figsize=(10, 5))
plt.bar(range(len(model_sk.coef_[0])), model_sk.coef_[0])
plt.xticks(range(len(model_sk.coef_[0])), ["topic_" + str(i + 1) for i in range(topic_num)], rotation=90)
plt.title("Coefficients of Topics")
plt.show()
